# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %%
df = pd.DataFrame(np.random.rand(7,3))
df.iloc[:4,1] = NA
df.iloc[:2,2] = NA
df = df.fillna(df.median())
df
# Out:
#           0         1         2
# 0  0.129502  0.323954  0.414623
# 1  0.617232  0.323954  0.414623
# 2  0.540189  0.323954  0.146852
# 3  0.941151  0.323954  0.414623
# 4  0.452897  0.323954  0.700972
# 5  0.376067  0.572241  0.356923
# 6  0.835065  0.248989  0.685194

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
  'key2' : ['one', 'two', 'one', 'two', 'one'],
  'data1' : np.random.randn(5),
  'data2' : np.random.randn(5)})
states = np.array(['Ohio', 'California', 'California', 'Ohio', 'Ohio'])
years = np.array([2005, 2005, 2006, 2005, 2006])
# df['data1'].groupby([states, years]).mean()
groubed =df.groupby(['key1', 'key2']).mean()
print(df)

#  df.groupby(['key1', 'key2']).size()
# df.groupby(['key1', 'key2'])[['data2']].mean()
print(groubed)
groubed.unstack()['data1','one']
# Out:
#   key1 key2     data1     data2
# 0    a  one -2.506738 -1.125762
# 1    a  two  0.261652 -0.893729
# 2    b  one -1.179970 -0.511120
# 3    b  two -1.161669  0.403087
# 4    a  one -0.100887 -0.519262
#               data1     data2
# key1 key2
# a    one  -1.303812 -0.822512
#      two   0.261652 -0.893729
# b    one  -1.179970 -0.511120
#      two  -1.161669  0.403087
# key1
# a   -1.303812
# b   -1.179970
# Name: (data1, one), dtype: float64

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
  'key2' : ['one', 'two', 'one', 'two', 'one'],
  'data1' : np.random.randn(5),
  'data2' : np.random.randn(5)})
print(df)
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.388996  0.934893
# 1    a  two  1.717129  0.383208
# 2    b  one -0.877041 -0.207134
# 3    b  two  0.543198  0.341941
# 4    a  one  0.370610  0.109681

# %%
# columns = pd.MultiIndex.from_arrays([['US', 'US', 'US', 'JP', 'JP'],
#   [1, 3, 5, 1, 3]],
#   names=['cty', 'tenor'])
def myFun(arr):
    return arr.mean() - arr.median()

grouped = df.groupby('key1')
print(grouped.agg(myFun))
grouped['data1'].describe()
# Out:
#          data1     data2
# key1
# a    -0.681104  0.047478
# b     0.000000  0.000000
#       count      mean       std       min       25%       50%       75%  \
# key1
# a       3.0 -0.781991  1.504634 -2.506738 -1.303812 -0.100887  0.080383
# b       2.0 -1.170820  0.012940 -1.179970 -1.175395 -1.170820 -1.166244
#
#            max
# key1
# a     0.261652
# b    -1.161669

# %%
# Load Melbourne_housing_FULL.csv dataset
dataset = pd.read_csv('C:/Users/jit/Downloads/archive (1)/Melbourne_housing_FULL.csv')
# Check and handle Missing 
dataset.replace(np.nan, dataset.mean(), inplace=True)
dataset = dataset.dropna()
dataset
# Remove duplicate records if it is exist
dataset.drop_duplicates(subset=None, keep='first', inplace=True)
# Check and Remove correlated attributes
corr = dataset['Rooms'].corr(dataset['Bedroom2'])
print(corr)
# out =  0.9308741267161045
dataset.pop('Bedroom2')
dataset
# Out:
# 0.8191258227403811
#            Suburb             Address  Rooms Type         Price Method  \
# 0      Abbotsford       68 Studley St      2    h  1.050173e+06     SS
# 1      Abbotsford        85 Turner St      2    h  1.480000e+06      S
# 2      Abbotsford     25 Bloomburg St      2    h  1.035000e+06      S
# 3      Abbotsford  18/659 Victoria St      3    u  1.050173e+06     VB
# 4      Abbotsford        5 Charles St      3    h  1.465000e+06     SP
# ...           ...                 ...    ...  ...           ...    ...
# 34852  Yarraville         13 Burns St      4    h  1.480000e+06     PI
# 34853  Yarraville       29A Murray St      2    h  8.880000e+05     SP
# 34854  Yarraville      147A Severn St      2    t  7.050000e+05      S
# 34855  Yarraville    12/37 Stephen St      3    h  1.140000e+06     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1.020000e+06     PI
#
#              SellerG        Date  Distance  Postcode  Bathroom       Car  \
# ...
